# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data/simpsons_script_lines.csv")
data = data.sort_values("episode_id", ascending=True)
data.head()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (4,5,6,12,13,14,15,16,17,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          id  episode_id  number                                  raw_text  \
# 148908  147           1     146  Homer Simpson: (GRABBING IT) Gimme that!
# 149010  248           1     247           Clerk: Less costume purchase --
# 149009  247           1     246                     Homer Simpson: Santa?
# 149008  246           1     245             Clerk: Less Santa training --
# 149007  245           1     244                     Homer Simpson: But...
#
#        timestamp_in_ms speaking_line character_id  location_id  \
# 148908          642000          TRUE            2         14.0
# 149010          940000          TRUE           28         19.0
# 149009          940000          TRUE            2         19.0
# 149008          940000          TRUE           28         19.0
# 149007          940000          TRUE            2         19.0
#
#        raw_character_text raw_location_text              spoken_words  \
# 148908      Homer Simpson  Circus of Values               Gimme that!
# 149010              Clerk  PERSONNEL OFFICE  Less costume purchase --
# 149009      Homer Simpson  PERSONNEL OFFICE                    Santa?
# 149008              Clerk  PERSONNEL OFFICE    Less Santa training --
# 149007      Homer Simpson  PERSONNEL OFFICE                    But...
#
#                  normalized_text word_count Unnamed: 13 Unnamed: 14  \
# 148908                gimme that          2         NaN         NaN
# 149010  less costume purchase --          4         NaN         NaN
# 149009                     santa          1         NaN         NaN
# 149008    less santa training --          4         NaN         NaN
# 149007                       but          1         NaN         NaN
#
#        Unnamed: 15 Unnamed: 16 Unnamed: 17  Unnamed: 18 Unnamed: 19
# 148908         NaN         NaN         NaN          NaN         NaN
# 149010         NaN         NaN         NaN          NaN         NaN
# 149009         NaN         NaN         NaN          NaN         NaN
# 149008         NaN         NaN         NaN          NaN         NaN
# 149007         NaN         NaN         NaN          NaN         NaN

# %%
frequency = data[data['normalized_text'].str.contains('help', na=False)]
# frequency = frequency.loc[:, ["episode_id", "timestamp_in_ms", "raw_character_text", "normalized_text"]]
frequency = frequency["raw_character_text"].value_counts()[:10]
frequency
# Out:
# Homer Simpson          270
# Bart Simpson           163
# Marge Simpson          149
# Lisa Simpson           147
# C. Montgomery Burns     33
# Ned Flanders            30
# Grampa Simpson          25
# Moe Szyslak             22
# Seymour Skinner         19
# Milhouse Van Houten     17
# Name: raw_character_text, dtype: int64

# %%
data = data.loc[:, ["episode_id", "raw_character_text", "normalized_text", "raw_text", "timestamp_in_ms", "speaking_line", "raw_location_text", "word_count"]]

data.to_csv("simpson_script_clean.csv")
